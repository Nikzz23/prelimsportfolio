# %%
from records import PersonalRecords
from DTRmodule import StudentDTR


class MainDisplay:

    def display():
        print("""
┌─────────────────────────────────────────────────────┐
╰─────────────────────────────────────────────────────╯
        Student Assistant Information System
  ───────────────────────────────────────────────────

        Students Assistants Personal Records
        
            [1] Add Student
            [2] Update Information
            [3] Search Student
            [4] Display All Records
            [5] Delete Student

  ───────────────────────────────────────────────────

        Student Assistants Daily Time Records
        
            [6] Display Student DTR
            [7] Time In
            [8] Time Out
            [9] Overtime
            [10] Modify Student DTR
            [11] Delete Date
            [12] Delete DTR File
            
            [13] Exit

  ───────────────────────────────────────────────────
        Select Command [1-11] """)

    def main():
        while True:
            MainDisplay.display()
            command = input(">>> ")
        
            if command == '1':
                PersonalRecords.add()
            elif command == '2':
                PersonalRecords.update()
            elif command == '3':
                PersonalRecords.search()
            elif command == '4':
                PersonalRecords.display()
            elif command == '5':
                PersonalRecords.delete()
            elif command == '6':
                StudentDTR.display()
            elif command == '7':
                StudentDTR.In()
            elif command == '8':
                StudentDTR.Out()
            elif command == '9':
                StudentDTR.overtime()
            elif command == '10':
                StudentDTR.modify()
            elif command == '11':
                StudentDTR.deletedate()
            elif command == '12':
                StudentDTR.deletefile()
            elif command == '13':
                break


if __name__ == "__main__":
    MainDisplay.main()
# Out:
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  5
# Deleting Data
# Enter Student ID:  B23-0001
# Confirm Deletion [y/n]: n
# Delete Cancelled
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  4
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#              Students Personal Information
#   ───────────────────────────────────────────────────
#
# ◉ Student Number: B23-0001
# 	Name: Nikolas
# 	Age: 19
# 	Sex: M
# 	Course/Program: BSCS
# 	Year: 1
# ◉ Student Number: G23-0001
# 	Name: Jane Doe
# 	Age: 22
# 	Sex: F
# 	Course/Program: BS Archi
# 	Year: 3
# ◉ Student Number: B20-8989
# 	Name: Jon
# 	Age: 21
# 	Sex: M
# 	Course/Program: BSA
# 	Year: 3
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  8
# Enter Student ID:  B20-8989
# Enter Date (ex. 1-29-24):
# You cant out, without having to in first
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  6
# Enter ID:  B20-8989
# ┌───────────────────────────────────────────────────────────────────────────────────────────────────┐
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────╯
#     Jon DTR | ID:B20-8989                     filename:[B20-8989] Jon DTR.csv
#   ─────────────────────────────────────────────────────────────────────────────────────────────────
# 	Date      |In (AM)   |Out (AM)  |In (PM)   |Out (PM)  |Overtime (In)  |Overtime (Out)
# 	2-10-24   |7:30      |          |          |          |               |
#
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  8
# Enter Student ID:  B20-8989
# Enter Date (ex. 1-29-24):  2-10-24
# You cant out, without having to in first
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  8
# Enter Student ID:  B20-8989
# Enter Date (ex. 1-29-24):  2-10-24
# Enter Time (ex. 9:00):  12:00
# AM [1] or PM [2] 1
# Departure added
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  6
# Enter ID:  B20-8989
# ┌───────────────────────────────────────────────────────────────────────────────────────────────────┐
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────╯
#     Jon DTR | ID:B20-8989                     filename:[B20-8989] Jon DTR.csv
#   ─────────────────────────────────────────────────────────────────────────────────────────────────
# 	Date      |In (AM)   |Out (AM)  |In (PM)   |Out (PM)  |Overtime (In)  |Overtime (Out)
# 	2-10-24   |7:30      |12:00     |          |          |               |
#
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  9
# Enter Student ID:  B20-8989
# In [1] or Out [2]:  1
# Enter Date (ex. 1-29-24):  2-10-24
# Enter Time (ex. 9:00 AM):  1:00 PM
# Overtime Added
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  6
# Enter ID:  B20-8989
# ┌───────────────────────────────────────────────────────────────────────────────────────────────────┐
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────╯
#     Jon DTR | ID:B20-8989                     filename:[B20-8989] Jon DTR.csv
#   ─────────────────────────────────────────────────────────────────────────────────────────────────
# 	Date      |In (AM)   |Out (AM)  |In (PM)   |Out (PM)  |Overtime (In)  |Overtime (Out)
# 	2-10-24   |7:30      |12:00     |          |          |1:00 PM        |
#
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  9
# Enter Student ID:  B20-8989
# In [1] or Out [2]:  2
# Enter Date (ex. 1-29-24):  2-10-24
# Enter Time (ex. 9:00 AM):  6:00
# Overtime Added
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  6
# Enter ID:  B20-8989
# ┌───────────────────────────────────────────────────────────────────────────────────────────────────┐
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────╯
#     Jon DTR | ID:B20-8989                     filename:[B20-8989] Jon DTR.csv
#   ─────────────────────────────────────────────────────────────────────────────────────────────────
# 	Date      |In (AM)   |Out (AM)  |In (PM)   |Out (PM)  |Overtime (In)  |Overtime (Out)
# 	2-10-24   |7:30      |12:00     |          |          |1:00 PM        |6:00
#
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  12
# Enter Student ID:  B20-8989
# Enter name:  Jon
# File Found
# Do you still want to delete the file [B20-8989] Jon DTR.csv? [y/n]  y
# File Deleted
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  4
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#              Students Personal Information
#   ───────────────────────────────────────────────────
#
# ◉ Student Number: B23-0001
# 	Name: Nikolas
# 	Age: 19
# 	Sex: M
# 	Course/Program: BSCS
# 	Year: 1
# ◉ Student Number: G23-0001
# 	Name: Jane Doe
# 	Age: 22
# 	Sex: F
# 	Course/Program: BS Archi
# 	Year: 3
# ◉ Student Number: B20-8989
# 	Name: Jon
# 	Age: 21
# 	Sex: M
# 	Course/Program: BSA
# 	Year: 3
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  5
# Deleting Data
# Enter Student ID:  B20-8989
# Confirm Deletion [y/n]: y
# Student Deleted
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  4
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#              Students Personal Information
#   ───────────────────────────────────────────────────
#
# ◉ Student Number: B23-0001
# 	Name: Nikolas
# 	Age: 19
# 	Sex: M
# 	Course/Program: BSCS
# 	Year: 1
# ◉ Student Number: G23-0001
# 	Name: Jane Doe
# 	Age: 22
# 	Sex: F
# 	Course/Program: BS Archi
# 	Year: 3
#
# ┌─────────────────────────────────────────────────────┐
# ╰─────────────────────────────────────────────────────╯
#         Student Assistant Information System
#   ───────────────────────────────────────────────────
#
#         Students Assistants Personal Records
#
#             [1] Add Student
#             [2] Update Information
#             [3] Search Student
#             [4] Display All Records
#             [5] Delete Student
#
#   ───────────────────────────────────────────────────
#
#         Student Assistants Daily Time Records
#
#             [6] Display Student DTR
#             [7] Time In
#             [8] Time Out
#             [9] Overtime
#             [10] Modify Student DTR
#             [11] Delete Date
#             [12] Delete DTR File
#
#             [13] Exit
#
#   ───────────────────────────────────────────────────
#         Select Command [1-11]
# >>>  13

# %%
B23-0001

CP102/refinedprelims/records.ipynb
